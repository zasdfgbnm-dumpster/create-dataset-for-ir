# %%
import sys
sys.path += ['/opt/apache-spark/python/lib/py4j-0.10.1-src.zip','/opt/apache-spark/python/lib/pyspark.zip']
from pyspark import *
from pyspark.sql import *
spark = SparkSession.builder.getOrCreate()

# %%
expir = spark.read.parquet("outputs/04/expir")
expir.show()
# Out:
# +----------+-----+--------------------+--------+--------------------+
# |       mid|index|                 vec|   state|          state_info|
# +----------+-----+--------------------+--------+--------------------+
# |   C135193|    0|[0.99638605, 0.99...|     gas|                    |
# |   C135206|    0|[0.9938847, 0.993...|     gas|                    |
# | C13524044|    0|[0.9629291, 0.903...|     gas|                    |
# |C135306455|    0|[0.9572527, 0.960...|     gas|                    |
# | C13532188|    0|[0.9132612, 0.913...|     gas|                    |
# | C13532779|    0|[0.99586576, 0.99...|     gas|                    |
# | C13551730|    0|[0.9972163, 0.997...|     gas|                    |
# | C13552211|    0|[0.9865672, 0.986...|     gas|                    |
# | C13552211|    1|[0.5686, 0.564, 0...|  liquid|              (NEAT)|
# | C13553190|    0|[0.5514, 0.5412, ...|   solid|(1 mg / 650 mg KB...|
# | C13558708|    0|[0.9736794, 0.974...|     gas|                    |
# |   C135615|    0|[0.9908236, 0.991...|     gas|                    |
# |   C135626|    0|[0.9949967, 0.994...|     gas|                    |
# |C135663988|    0|[0.9590344, 0.947...|     gas|                    |
# |   C135671|    0|[0.9987374, 0.998...|     gas|                    |
# | C13567403|    0|[0.8721, 0.869, 0...|  liquid|              (NEAT)|
# | C13568779|    0|[0.6276, 0.6293, ...|   solid|        (NUJOL MULL)|
# |   C135706|    0|[0.7413059, 0.725...|   solid|(1.0% IN KBr PELLET)|
# |   C135739|    0|[0.41879603, 0.39...|solution|(1% CCl4 FOR 2-7....|
# |   C135739|    1|[0.6526, 0.6607, ...|   solid|        (NUJOL MULL)|
# +----------+-----+--------------------+--------+--------------------+
# only showing top 20 rows

# %%
import matplotlib.pyplot as plt
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
for i in expir.rdd.map(lambda x : x["vec"]).take(100):
    plt.plot(i)
    plt.show()
